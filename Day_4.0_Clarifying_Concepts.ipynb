# %% [markdown]
# ### Day 4.0
#
# # Recap of Day 3, Tips
# <img src = "images/logo.jpg", width="100" align="left">
#
# <br><br><br><br>Ram Narasimhan

# %% [markdown]
# Open this notebook on your laptops. Let's go these together, slowly, step-by-step.
#
# We will work on it together

# %% [markdown]
# Tips for Day 4:
#
# # Jupyter Tips
#
# ### How to move cells up or down...
#
# ### How to Select Multiple Cells and copy them?
#
# ### How to Open Files in a Different Folder?

# %%
#This is a nice way to find out what your current_working_directory(cwd) is...
import os
os.getcwd()
# Out:
# 'c:\\Users\\Ram\\Py Library\\data-analysis-using-python'

# %%
#this is a very Pythonic way to find out all the files in the directory
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'admin',
#  'basic-line.html',
#  'checklist',
#  'data',
#  'Day 1 Python Intro',
#  'Day 2 Python Viz',
#  'Day 3 Big Data - Time Series',
#  'Day 4 Big Data ML',
#  'Day 5 Cloud Computing',
#  'Day 6 IoT',
#  'Day 7 Digital Twin & Simulation',
#  'Day 8 Brilliant Factory',
#  'Day 9 Team Presentations -  Case Studies',
#  'Day_0_Checklist.ipynb',
#  'Day_1.1_Introduction to Jupyter Notebooks.ipynb',
#  'Day_1.2_Getting Started with Python.ipynb',
#  'Day_1.3_Arithmetic_and_String_Operations in Python.ipynb',
#  'Day_1.4_Python Lists.ipynb',
#  'Day_1.5_Exercise_Lists_based.ipynb',
#  'Day_1.5_Exercise_SOLUTION_Lists_based.ipynb',
#  'Day_2.0_Assorted.ipynb',
#  'Day_2.1_Using Variables.ipynb',
#  'Day_2.2_Flow of Control in Python.ipynb',
#  'Day_2.3_Functions.ipynb',
#  'Day_2.4_Python Dictionaries.ipynb',
#  'Day_2.5_List_Slicing_Extra.ipynb',
#  'Day_2.5_SOLUTION_to_Exercise.ipynb',
#  'Day_2_List Comprehensions.ipynb',
# ...

# %%
#now we can store this in a Python list and do anything with it...
all_my_files = os.listdir()

for m in all_my_files:
    if m.startswith("D"):
        print(m)
# Out:
# Day 1 Python Intro
# Day 2 Python Viz
# Day 3 Big Data - Time Series
# Day 4 Big Data ML
# Day 5 Cloud Computing
# Day 6 IoT
# Day 7 Digital Twin & Simulation
# Day 8 Brilliant Factory
# Day 9 Team Presentations -  Case Studies
# Day_0_Checklist.ipynb
# Day_1.1_Introduction to Jupyter Notebooks.ipynb
# Day_1.2_Getting Started with Python.ipynb
# Day_1.3_Arithmetic_and_String_Operations in Python.ipynb
# Day_1.4_Python Lists.ipynb
# Day_1.5_Exercise_Lists_based.ipynb
# Day_1.5_Exercise_SOLUTION_Lists_based.ipynb
# Day_2.0_Assorted.ipynb
# Day_2.1_Using Variables.ipynb
# Day_2.2_Flow of Control in Python.ipynb
# Day_2.3_Functions.ipynb
# Day_2.4_Python Dictionaries.ipynb
# Day_2.5_List_Slicing_Extra.ipynb
# Day_2.5_SOLUTION_to_Exercise.ipynb
# Day_2_List Comprehensions.ipynb
# Day_2_Reading A File.ipynb
# Day_3.0_Start_and_Tips.ipynb
# Day_3.1_Plotting in Python Using Seaborn.ipynb
# Day_3.2 Pandas_At_Work_Movies_Example.ipynb
# ...

# %%
#to combine paths, just use join separated by commas
os.path.join(os.getcwd(), "data")
os.path.join(os.getcwd(), "data", "Crude Oil Data")

#Notice that windows in adding two(!) backslashes. This was causing us problems yesterday.

# %% [markdown]
# # How to get Jupyter into other PC's
#
# Just go to Anaconda Download, and get the lastest Python 3.x.
# Then use Anaconda Navigator.

# %% [markdown]
# # <div class="alert alert-block alert-success"> 4 commands to start with...    </div>
#
# ### I almost always use these...

# %%
#import numpy as np
#import matplotlib.pyplot as plt
#import pandas as pd
#%matplotlib inline
dir(np)
# Out:
# ['ALLOW_THREADS',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'MachAr',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'PackageLoader',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__doc__',
#  '__file__',
#  '__git_revision__',
#  '__loader__',
#  '__mkl_version__',
# ...

# %% [markdown]
# # Enumerating Lists

# %% [markdown]
# # Dictionaries with 2 of more values...

# %% [markdown]
# # Pandas

# %% [markdown]
# ![Image](images/Boolean-Indexing-Example.png)

# %% [markdown]
# ### Important Tip: A DataFrame is nothing but a Dictionary.
# It is actually a special kind of dictionary, with more properties...
#
# Let us see...

# %%
#capitals["Key"]
#df["ColumnName"]

# %%
#First, let's create a couple of lists
letters = list("ABCDEFGHIJKLMNOPQRSTUVWXYZ")
numbers = range(1,27)

# %%
#How to create a DataFrame...
import pandas as pd
df = pd.DataFrame({"letters" : letters, "numbers": numbers})

# %%
df
# Out:
#    letters  numbers
# 0        A        1
# 1        B        2
# 2        C        3
# 3        D        4
# 4        E        5
# 5        F        6
# 6        G        7
# 7        H        8
# 8        I        9
# 9        J       10
# 10       K       11
# 11       L       12
# 12       M       13
# 13       N       14
# 14       O       15
# 15       P       16
# 16       Q       17
# 17       R       18
# 18       S       19
# 19       T       20
# 20       U       21
# 21       V       22
# 22       W       23
# 23       X       24
# 24       Y       25
# 25       Z       26

# %%
#Tell me how to rename a Data Frame (pandas)
#df.rename(columns=["letters"])

# %% [markdown]
# ![Questions](images/questions.png)
