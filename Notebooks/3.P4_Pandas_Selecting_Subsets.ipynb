# %% [markdown]
# # SELF-PRACTICE
#
# ### Day 3
#
# # Pandas: Selecting Data to Work with
#
# ## Using `Boolean Masks`
# <img src = "images/logo.jpg" width="100" align="left">
#
# Ram Narasimhan

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("data/Crude Oil Data/CrudeOilProduction.csv")

# %%
df.columns

# %% [markdown]
# # <div class="alert alert-block alert-warning"> View one column </div>

# %%
df['Time']

# %% [markdown]
# # View only the column of countries

# %% [markdown]
# # <div class="alert alert-block alert-warning">  How many 'unique' values are there in any column?
#
# ### How many unique Country Codes are there in the data frame?

# %%
#df['Country'].unique()
sorted(df['Country'].unique())
# Out:
# ['AGO',
#  'ALB',
#  'ARE',
#  'ARG',
#  'ARM',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BEL',
#  'BEN',
#  'BGD',
#  'BGR',
#  'BHR',
#  'BIH',
#  'BLR',
#  'BOL',
#  'BRA',
#  'BRN',
#  'BWA',
#  'CAN',
#  'CHE',
#  'CHL',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COG',
#  'COL',
#  'CRI',
#  'CUB',
#  'CYP',
#  'CZE',
#  'DEU',
#  'DNK',
#  'DOM',
#  'DZA',
#  'ECU',
#  'EGY',
#  'ERI',
#  'ESP',
#  'EST',
#  'ETH',
#  'EU28',
#  'FIN',
#  'FRA',
#  'G20',
#  'GAB',
#  'GBR',
#  'GEO',
#  'GHA',
#  'GRC',
#  'GTM',
#  'HKG',
#  'HND',
#  'HRV',
#  'HTI',
#  'HUN',
#  'IDN',
#  'IND',
#  'IRL',
#  'IRN',
#  'IRQ',
#  'ISL',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JOR',
#  'JPN',
#  'KAZ',
#  'KEN',
#  'KGZ',
#  'KHM',
#  'KOR',
#  'KWT',
#  'LBN',
#  'LBY',
#  'LKA',
#  'LTU',
#  'LUX',
#  'LVA',
#  'MAR',
#  'MDA',
#  'MEX',
#  'MKD',
#  'MLT',
#  'MMR',
#  'MNE',
#  'MNG',
#  'MOZ',
#  'MYS',
#  'NAM',
#  'NER',
#  'NGA',
#  'NIC',
#  'NLD',
#  'NOR',
#  'NPL',
#  'NZL',
#  'OECD',
# ...

# %% [markdown]
# # Your turn: How many countries (number) are there?

# %% [markdown]
# # Can you subset only to include France?

# %%
condition = df['Country'] == 'FRA'

# %%
df[condition]
# Out:
#     Country Indicator Subject Units Frequency  Time  Quantity Flag Codes
# 392     FRA   OILPROD     TOT  KTOE         A  1960       NaN          L
# 393     FRA   OILPROD     TOT  KTOE         A  1961       NaN          L
# 394     FRA   OILPROD     TOT  KTOE         A  1962       NaN          L
# 395     FRA   OILPROD     TOT  KTOE         A  1963       NaN          L
# 396     FRA   OILPROD     TOT  KTOE         A  1964       NaN          L
# 397     FRA   OILPROD     TOT  KTOE         A  1965       NaN          L
# 398     FRA   OILPROD     TOT  KTOE         A  1966       NaN          L
# 399     FRA   OILPROD     TOT  KTOE         A  1967       NaN          L
# 400     FRA   OILPROD     TOT  KTOE         A  1968       NaN          L
# 401     FRA   OILPROD     TOT  KTOE         A  1969       NaN          L
# 402     FRA   OILPROD     TOT  KTOE         A  1970       NaN          L
# 403     FRA   OILPROD     TOT  KTOE         A  1971  1861.644        NaN
# ...

# %% [markdown]
# # Can you subset only to include Zimbabwe?

# %% [markdown]
# # Can you subset only to for the year = 2015?

# %%
condition2 = df['Country']=='NOR'
condition1 = df['Quantity'] > 100000
df[condition2 & condition1]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 7922    False
# 7923    False
# 7924    False
# 7925    False
# 7926    False
# 7927    False
# 7928    False
# 7929    False
# 7930    False
# 7931    False
# 7932    False
# 7933    False
# 7934    False
# 7935    False
# 7936    False
# 7937    False
# 7938    False
# 7939    False
# 7940    False
# 7941    False
# 7942    False
# 7943    False
# 7944    False
# 7945    False
# 7946    False
# 7947    False
# 7948    False
# 7949    False
# 7950    False
# 7951    False
# ...

# %%
condition2 = df['Time']==2015

# %%
df[condition2]

# %% [markdown]
# # Your Turn

# %% [markdown]
# # Create a SUBSET of a data frame with:
#
# Country = Norway

# %% [markdown]
# # We only want to keep those rows where `Quantity` > 100,000

# %% [markdown]
# # Print only the Country & the Quantity, condtion: Quantity > 100,000

# %% [markdown]
# ![Questions](images/questions.png)

# %%
df = pd.DataFrame ({'a' : np.random.randn(6),
             'c' : np.random.randn(6)})

#if you want to apply sum just to one particular row, use .loc
df.loc[3].sum()

#If you want to apply a function to ALL the rows, use apply with axis=1 (meaning row by row)
df.apply(sum, axis=1)
# Out:
# 0.6807051420570589
