# %% [markdown]
# ### ` Notebooks/data/WorldPopulation/`

# %% [markdown]
# # 3.4
#
# ### Day 3
#
# # Pandas: Selecting Data to Work with
#
# ## Using `Boolean Masks`
# <img src = "images/logo.jpg" width="100" align="left">
#
# Ram Narasimhan

# %%
import pandas as pd

# %% [markdown]
# # <div class="alert alert-block alert-warning">  Let's read the `Countries` Data Set
# ### in the data/ directory

# %%
countries = pd.read_csv("data/WorldPopulation/countries.csv", 
                        encoding = "ISO-8859-1")

# %% [markdown]
# We have read the file `countries.csv` and saved the results to a data frame called `countries`

# %%
countries.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965     ...      \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0     ...
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0     ...
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0     ...
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0     ...
# 4    14375.0    15370.0    16412.0    17469.0    18549.0     ...
#
#          2007        2008        2009        2010        2011        2012  \
# ...

# %% [markdown]
# ### Important (and good practice) to give all your columns Good, Descriptive Names
#
# # <div class="alert alert-block alert-warning">  Renaming Columns </div>
#
# ## Use the df.rename(columns = {"old name": "new name"})

# %%
countries.rename(columns={"Country Name": "Name"})
# Out:
#                                                   Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
countries
# Out:
#                                                   Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %% [markdown]
# <img src = "images/caution.png" width="50" align="left">
# # Be Careful about :
#
# ### <div class="alert alert-block alert-info">Be sure that the names have been changed permanently!</div>

# %%
countries.columns
# Looks like it didn't get replaced! What happened?
# Out:
# Index(['Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960',
#        '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016'],
#       dtype='object')

# %%
countries.rename(columns={'Country Name' : "Name", "Country Code": "Code"}, inplace=True)
countries.head() #Now it is permanently replaced, thanks to using `inplace=True`
# Out:
#           Name Code     Indicator Name Indicator Code       1960       1961  \
# 0        Aruba  ABW  Population, total    SP.POP.TOTL    54211.0    55438.0
# 1  Afghanistan  AFG  Population, total    SP.POP.TOTL  8996351.0  9166764.0
# 2       Angola  AGO  Population, total    SP.POP.TOTL  5643182.0  5753024.0
# 3      Albania  ALB  Population, total    SP.POP.TOTL  1608800.0  1659800.0
# 4      Andorra  AND  Population, total    SP.POP.TOTL    13411.0    14375.0
#
#         1962       1963       1964       1965     ...            2007  \
# 0    56225.0    56695.0    57032.0    57360.0     ...        101220.0
# 1  9345868.0  9533954.0  9731361.0  9938414.0     ...      26616792.0
# 2  5866061.0  5980417.0  6093321.0  6203299.0     ...      20997687.0
# 3  1711319.0  1762621.0  1814135.0  1864791.0     ...       2970017.0
# 4    15370.0    16412.0    17469.0    18549.0     ...         82683.0
#
#          2008        2009        2010        2011        2012        2013  \
# ...

# %% [markdown]
# # <div class="alert alert-block alert-warning">  How many 'unique' values are there in any column?
#
# ### How many unique Country Codes are there in the data frame?

# %%
countries["Country Code"].unique()
#countries.columns
# Out:
# array(['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG', 'ARM',
#        'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',
#        'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL',
#        'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CEB', 'CHE',
#        'CHI', 'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM',
#        'CPV', 'CRI', 'CSS', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU',
#        'DJI', 'DMA', 'DNK', 'DOM', 'DZA', 'EAP', 'EAR', 'EAS', 'ECA',
#        'ECS', 'ECU', 'EGY', 'EMU', 'ERI', 'ESP', 'EST', 'ETH', 'EUU',
#        'FCS', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', 'GEO',
#        'GHA', 'GIB', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL',
#        'GTM', 'GUM', 'GUY', 'HIC', 'HKG', 'HND', 'HPC', 'HRV', 'HTI',
#        'HUN', 'IBD', 'IBT', 'IDA', 'IDB', 'IDN', 'IDX', 'IMN', 'IND',
#        'INX', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR',
# ...

# %% [markdown]
# # <div class="alert alert-block alert-warning"> String Operations on Columns

# %% [markdown]
# In your work, there will be many columns that will be "Strings." (Things that are not numeric.) Those columns can be very informative! And String manipulation is very easy in Pandas.

# %%
#Take a pandas dataframe String column and split it into different words...
countries['Name'].str.split()
# Out:
# 0                                                [Aruba]
# 1                                          [Afghanistan]
# 2                                               [Angola]
# 3                                              [Albania]
# 4                                              [Andorra]
# 5                                          [Arab, World]
# 6                               [United, Arab, Emirates]
# 7                                            [Argentina]
# 8                                              [Armenia]
# 9                                      [American, Samoa]
# 10                               [Antigua, and, Barbuda]
# 11                                           [Australia]
# 12                                             [Austria]
# 13                                          [Azerbaijan]
# 14                                             [Burundi]
# 15                                             [Belgium]
# ...

# %% [markdown]
# <img src = "images/fun/fun_activity.jpg" width="100" align="right">
# ## Try this now:
#
# # <div class="alert alert-block alert-warning"> Use Pandas & print the Names of all the countries that contain the string `"bia"`

# %% [markdown]
# # <div class="alert alert-block alert-success"> How many can you all guess?!</div>
#
# #### I was able to guess only 4

# %% [markdown]
# ### We can use many of the `STRING` operations on Columns
#
# Let's look at this very briefly

# %%
cond = countries['Name'].str.contains('bia')
countries[cond]
# Out:
#              Name Country Code     Indicator Name Indicator Code        1960  \
# 43       Colombia          COL  Population, total    SP.POP.TOTL  16480383.0
# 84    Gambia, The          GMB  Population, total    SP.POP.TOTL    367928.0
# 169       Namibia          NAM  Population, total    SP.POP.TOTL    602544.0
# 203  Saudi Arabia          SAU  Population, total    SP.POP.TOTL   4086539.0
# 212        Serbia          SRB  Population, total    SP.POP.TOTL         NaN
# 262        Zambia          ZMB  Population, total    SP.POP.TOTL   3044846.0
#
#            1961        1962        1963        1964        1965     ...      \
# 43   16982315.0  17500171.0  18033550.0  18581974.0  19144223.0     ...
# 84     376737.0    383523.0    389072.0    394553.0    400861.0     ...
# 169    617277.0    632654.0    648661.0    665282.0    682551.0     ...
# 203   4218879.0   4362864.0   4516659.0   4677404.0   4843635.0     ...
# ...

# %%
#Whenever you have a condition, create a "MASK". Then apply that MASK to the data frame...
condition = countries['Name'].str.contains("bia")
small_df = countries[condition]
print(small_df['Name'])
# Out:
# 43         Colombia
# 84      Gambia, The
# 169         Namibia
# 203    Saudi Arabia
# 212          Serbia
# 262          Zambia
# Name: Name, dtype: object

# %% [markdown]
# ### How did this work?
#
# - First, we created a condition. In this case the `condition` was all the rows in the column called 'Name' that contained the substring "bia."
# - If you print out 'condition' you will see that it is a long series of 0 and 1. (Called a MASK)
# - Next we use that mask to filter out all the unwanted rows and keep only the wanted rows.
# - `countries[condition]` is a very small dataframe. All the country Names that didn't satisfy this condition were removed.
# - In fact, this dataframe has only 6 rows
#
# - The last thing we need to do is to print out the Names.
# - `small_df` has many columns. But we just print out the one we are interested in

# %% [markdown]
# ![Questions](images/questions.png)
